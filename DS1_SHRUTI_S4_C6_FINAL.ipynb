# %% [markdown]
# # GOLD ATLANTIS : REPAYING LOANS

# %% [markdown]
# ##### IMPORTING REQUIRED LIBRARIES AND CHECKING THEIR VERSIONS¶

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tabulate import tabulate

# %%
print("Pandas version: ",pd.__version__)
print("Seaborn version: ",sns.__version__)
# Out:
# Pandas version:  1.4.2
# Seaborn version:  0.11.2

# %% [markdown]
# ##### LEVEL 0 ANALYSIS

# %% [markdown]
# ###### READ CSV FILE

# %%
df=pd.read_csv("DS1_C6_S4_Credit_Data_Hackathon.csv ")
df
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0          100002       1         Cash loans      M   N     Y             0
# 1          100003       0         Cash loans      F   N     N             0
# 2          100004       0    Revolving loans      M   Y     Y             0
# 3          100006       0         Cash loans      F   N     Y             0
# 4          100007       0         Cash loans      M   N     Y             0
# ...           ...     ...                ...    ...  ..   ...           ...
# 99995      216086       0         Cash loans      F   N     Y             1
# 99996      216087       0         Cash loans      F   N     Y             1
# 99997      216088       0         Cash loans      F   Y     Y             0
# 99998      216089       0         Cash loans      F   Y     N             0
# 99999      216090       0    Revolving loans      M   Y     Y             0
#
# ...

# %% [markdown]
# ##### TOP 5 ROWS

# %%
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0      100002       1         Cash loans      M   N     Y             0
# 1      100003       0         Cash loans      F   N     N             0
# 2      100004       0    Revolving loans      M   Y     Y             0
# 3      100006       0         Cash loans      F   N     Y             0
# 4      100007       0         Cash loans      M   N     Y             0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_GOODS_PRICE  ... DAYS_EMPLOYED MOBILE  \
# 0          202500.0    406597.5         351000.0  ...          -637      1
# 1          270000.0   1293502.5        1129500.0  ...         -1188      1
# 2           67500.0    135000.0         135000.0  ...          -225      1
# 3          135000.0    312682.5         297000.0  ...         -3039      1
# 4          121500.0    513000.0         513000.0  ...         -3038      1
#
#   WORK_PHONE HOME_PHONE  MOBILE_REACHABLE  FLAG_EMAIL  OCCUPATION_TYPE  \
# ...

# %% [markdown]
# ##### BOTTOM 5 ROWS

# %%
df.tail()
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 99995      216086       0         Cash loans      F   N     Y             1
# 99996      216087       0         Cash loans      F   N     Y             1
# 99997      216088       0         Cash loans      F   Y     Y             0
# 99998      216089       0         Cash loans      F   Y     N             0
# 99999      216090       0    Revolving loans      M   Y     Y             0
#
#        AMT_INCOME_TOTAL  AMT_CREDIT  AMT_GOODS_PRICE  ... DAYS_EMPLOYED  \
# 99995          157500.0    755190.0         675000.0  ...          -232
# 99996          225000.0    284400.0         225000.0  ...          -182
# 99997          135000.0   1262583.0        1102500.0  ...         -4805
# 99998          135000.0    225000.0         225000.0  ...          -340
# 99999          202500.0    337500.0         337500.0  ...         -3230
#
#       MOBILE WORK_PHONE HOME_PHONE  MOBILE_REACHABLE  FLAG_EMAIL  \
# ...

# %% [markdown]
# ##### COLUMN NAMES

# %%
df.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'GENDER', 'Car', 'House',
#        'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_GOODS_PRICE',
#        'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'DAYS_EMPLOYED', 'MOBILE', 'WORK_PHONE',
#        'HOME_PHONE', 'MOBILE_REACHABLE', 'FLAG_EMAIL', 'OCCUPATION_TYPE',
#        'CNT_FAM_MEMBERS', 'APPLICATION_DAY', 'TOTAL_DOC_SUBMITTED'],
#       dtype='object')

# %% [markdown]
# ##### SHAPE OF DF

# %%
df.shape
# Out:
# (100000, 24)

# %% [markdown]
# ##### INFORMATION OF DATASET

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 24 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   SK_ID_CURR           100000 non-null  int64
#  1   TARGET               100000 non-null  int64
#  2   NAME_CONTRACT_TYPE   100000 non-null  object
#  3   GENDER               100000 non-null  object
#  4   Car                  100000 non-null  object
#  5   House                100000 non-null  object
#  6   CNT_CHILDREN         100000 non-null  int64
#  7   AMT_INCOME_TOTAL     100000 non-null  float64
#  8   AMT_CREDIT           100000 non-null  float64
#  9   AMT_GOODS_PRICE      99919 non-null   float64
#  10  NAME_TYPE_SUITE      99595 non-null   object
#  11  NAME_INCOME_TYPE     100000 non-null  object
#  12  NAME_EDUCATION_TYPE  100000 non-null  object
#  13  NAME_FAMILY_STATUS   100000 non-null  object
#  14  DAYS_EMPLOYED        100000 non-null  int64
# ...

# %% [markdown]
# ##### MISSING VALUES

# %%
df.isnull().sum()
# Out:
# SK_ID_CURR                 0
# TARGET                     0
# NAME_CONTRACT_TYPE         0
# GENDER                     0
# Car                        0
# House                      0
# CNT_CHILDREN               0
# AMT_INCOME_TOTAL           0
# AMT_CREDIT                 0
# AMT_GOODS_PRICE           81
# NAME_TYPE_SUITE          405
# NAME_INCOME_TYPE           0
# NAME_EDUCATION_TYPE        0
# NAME_FAMILY_STATUS         0
# DAYS_EMPLOYED              0
# MOBILE                     0
# WORK_PHONE                 0
# HOME_PHONE                 0
# MOBILE_REACHABLE           0
# FLAG_EMAIL                 0
# OCCUPATION_TYPE        31224
# CNT_FAM_MEMBERS            1
# APPLICATION_DAY            0
# TOTAL_DOC_SUBMITTED        0
# dtype: int64

# %% [markdown]
# ##### SEPERATING CATEGORICAL AND NUMERICAL COLUMNS:

# %%
def sep_data_type(df):
    CAT=[]
    NUM=[]
    for i in df.columns:
        if df[i].nunique() <20:
            CAT.append(i)
        else:
            NUM.append(i)
    return CAT,NUM
CAT,NUM= sep_data_type(df)
table=[CAT,NUM]
print(tabulate({"Categorical":CAT,
                "Numerical": NUM}, headers = ["categorical", "Numerical"]))
# Out:
# categorical          Numerical
# -------------------  ----------------
# TARGET               SK_ID_CURR
# NAME_CONTRACT_TYPE   AMT_INCOME_TOTAL
# GENDER               AMT_CREDIT
# Car                  AMT_GOODS_PRICE
# House                DAYS_EMPLOYED
# CNT_CHILDREN
# NAME_TYPE_SUITE
# NAME_INCOME_TYPE
# NAME_EDUCATION_TYPE
# NAME_FAMILY_STATUS
# MOBILE
# WORK_PHONE
# HOME_PHONE
# MOBILE_REACHABLE
# FLAG_EMAIL
# OCCUPATION_TYPE
# CNT_FAM_MEMBERS
# APPLICATION_DAY
# TOTAL_DOC_SUBMITTED

# %% [markdown]
# ##### User defined functions for level 1 analysis of categorical columns

# %%
def info_of_cat(col): 
    print("Unique values are:", df[col].unique())                        #unique values
    print("Mode is: ",df[col].mode()[0])                               #mode
    print("Number of missing values are :",df[col].isnull().sum())     #missing values 
    if df[col].isnull().sum() > 0:
        print(f"\nThere are null values in the {col} column")

# %% [markdown]
# ##### User defined functions for level 1 analysis of numerical columns

# %%
def info_of_num(col): 
    print("Mean is: ",df[col].mean())                               #mode
    print("Number of missing values are :",df[col].isnull().sum())     #missing values 
    if df[col].isnull().sum() > 0:
        print(f"\nThere are null values in the {col} column")

# %% [markdown]
# ##### MISSING VALUE TREATMENT:

# %%
info_of_cat("OCCUPATION_TYPE")
# Out:
# Unique values are: ['Laborers' 'Core staff' 'Accountants' 'Managers' nan 'Drivers'
#  'Sales staff' 'Cleaning staff' 'Cooking staff' 'Private service staff'
#  'Medicine staff' 'Security staff' 'High skill tech staff'
#  'Waiters/barmen staff' 'Low-skill Laborers' 'Realty agents' 'Secretaries'
#  'IT staff' 'HR staff']
# Mode is:  Laborers
# Number of missing values are : 31224
#
# There are null values in the OCCUPATION_TYPE column

# %%
occu_tm = df.OCCUPATION_TYPE.mode()[0]
print(occu_tm)
df["OCCUPATION_TYPE"].fillna(occu_tm, inplace = True)
# Out:
# Laborers

# %%
info_of_cat("NAME_TYPE_SUITE")
# Out:
# Unique values are: ['Unaccompanied' 'Family' 'Spouse, partner' 'Children' 'Other_A' nan
#  'Other_B' 'Group of people']
# Mode is:  Unaccompanied
# Number of missing values are : 405
#
# There are null values in the NAME_TYPE_SUITE column

# %%
name_tm = df.NAME_TYPE_SUITE.mode()[0]
print(name_tm)
df["NAME_TYPE_SUITE"].fillna(name_tm, inplace = True)
# Out:
# Unaccompanied

# %%
info_of_num("AMT_GOODS_PRICE")
# Out:
# Mean is:  538345.1489706662
# Number of missing values are : 81
#
# There are null values in the AMT_GOODS_PRICE column

# %%
amt_tm = df.AMT_GOODS_PRICE.mean()
print(amt_tm)
df["AMT_GOODS_PRICE"].fillna(amt_tm, inplace = True)
# Out:
# 538345.1489706662

# %%
df.isnull().sum()
# Out:
# SK_ID_CURR             0
# TARGET                 0
# NAME_CONTRACT_TYPE     0
# GENDER                 0
# Car                    0
# House                  0
# CNT_CHILDREN           0
# AMT_INCOME_TOTAL       0
# AMT_CREDIT             0
# AMT_GOODS_PRICE        0
# NAME_TYPE_SUITE        0
# NAME_INCOME_TYPE       0
# NAME_EDUCATION_TYPE    0
# NAME_FAMILY_STATUS     0
# DAYS_EMPLOYED          0
# MOBILE                 0
# WORK_PHONE             0
# HOME_PHONE             0
# MOBILE_REACHABLE       0
# FLAG_EMAIL             0
# OCCUPATION_TYPE        0
# CNT_FAM_MEMBERS        1
# APPLICATION_DAY        0
# TOTAL_DOC_SUBMITTED    0
# dtype: int64

# %% [markdown]
# # LEVEL 1 UNIVARIATE- ANALYSIS

# %% [markdown]
# ## CATEGORICAL

# %%
data = df["TARGET"].value_counts()                                  
pie, ax = plt.subplots(1, 2, figsize = [20,6])                                                             
labels =data.keys() 
colors=['#66b3ff','#99ff99']
ax[0].pie(x = data, autopct = "%.1f%%", labels = labels, pctdistance = 0.9,colors=colors);
                                                                            
sns.countplot(x = df["TARGET"], ax = ax[1], order = df["TARGET"].value_counts().index,color='c',edgecolor='c')                                                                                               
plt.title("TARGET");

# %% [markdown]
# ##### INTERPRETATION: 91.9% ARE Target variable 1 - client with payment difficulties: he/she had late payment more than X days on at least one of the first Y installments of the loan in our sample, 0 - all other cases.

# %%
data = df["NAME_CONTRACT_TYPE"].value_counts()                                  
pie, ax = plt.subplots(1, 2, figsize = [20,6])                                                             
labels =data.keys() 
colors=['#66b3ff','#99ff99']
ax[0].pie(x = data, autopct = "%.1f%%", labels = labels, pctdistance = 0.9,colors=colors);
                                                                            
sns.countplot(x = df["NAME_CONTRACT_TYPE"], ax = ax[1], order = df["NAME_CONTRACT_TYPE"].value_counts().index,color='c',edgecolor='c')                                                                                               
plt.title("NAME_CONTRACT_TYPE");

# %% [markdown]
# ##### INTERPRETATION: 90.5% ARE CASH TYPE AND 9.5% ARE REVOLVING LOANS.

# %%
data = df["GENDER"].value_counts()                                  
pie, ax = plt.subplots(1, 2, figsize = [20,6])                                                             
labels =data.keys() 
colors=['#66b3ff','#99ff99']
ax[0].pie(x = data, autopct = "%.1f%%", labels = labels, pctdistance = 0.9,colors=colors);
                                                                            
sns.countplot(x = df["GENDER"], ax = ax[1], order = df["GENDER"].value_counts().index,color='c',edgecolor='c')                                                                                               
plt.title("GENDER");

# %% [markdown]
# ##### INTERPRETATION: THERE ARE MORE FEMALE CLIENTS THAN MALE.

# %%
data = df["Car"].value_counts()                                  
pie, ax = plt.subplots(1, 2, figsize = [20,6])                                                             
labels =data.keys() 
colors=['#66b3ff','#99ff99']
ax[0].pie(x = data, autopct = "%.1f%%", labels = labels, pctdistance = 0.9,colors=colors);
                                                                            
sns.countplot(x = df["Car"], ax = ax[1], order = df["Car"].value_counts().index,color='c',edgecolor='c')                                                                                               
plt.title("Car");

# %% [markdown]
# ##### INTERPRETATION: CLIENTS WITH NO CAR HAS HIGHER PROPORTION THAN CLIENTS HAVING CAR.

# %%
data = df["House"].value_counts()                                  
pie, ax = plt.subplots(1, 2, figsize = [20,6])                                                             
labels =data.keys() 
colors=['#66b3ff','#99ff99']
ax[0].pie(x = data, autopct = "%.1f%%", labels = labels, pctdistance = 0.9,colors=colors);
                                                                            
sns.countplot(x = df["House"], ax = ax[1], order = df["House"].value_counts().index,color='c',edgecolor='c')                                                                                               
plt.title("House");

# %% [markdown]
# ##### INTERPRETATION: MOST OF THE CLIENTS HAVE HOUSE WITH 69.3% PROPORTION.

# %%
data = df["CNT_CHILDREN"].value_counts()                                  
pie, ax = plt.subplots(1, 2, figsize = [20,6])                                                             
labels =data.keys() 
colors=['#66b3ff','#99ff99','#ffcc99','#ff55cc','y']
ax[0].pie(x = data, autopct = "%.1f%%", labels = labels, pctdistance = 0.9,colors=colors,explode = [0,0,0,0,0.2,0.3,0.4,0,0,0,0.9,0.5]);
                                                                            
sns.countplot(x = df["CNT_CHILDREN"], ax = ax[1], order = df["CNT_CHILDREN"].value_counts().index,color='c',edgecolor='c')                                                                                               
plt.title("CNT_CHILDREN");

# %% [markdown]
# ##### INTERPRETATION: 70% OF CLIENTS HAVE NO CHILDREN AND ONLY 20% HAVE ONE.

# %%
df["NAME_TYPE_SUITE"].unique()
# Out:
# array(['Unaccompanied', 'Family', 'Spouse, partner', 'Children',
#        'Other_A', 'Other_B', 'Group of people'], dtype=object)

# %%
data = df["NAME_TYPE_SUITE"].value_counts()                                  
pie, ax = plt.subplots(1, 2, figsize = [20,6])                                                             
labels =data.keys() 
colors=['#66b3ff','#99ff99','#ffcc99','#ff55cc','y']
ax[0].pie(x = data, autopct = "%.1f%%", labels = labels, pctdistance = 0.8,colors=colors);
                                                                            
sns.countplot(x = df["NAME_TYPE_SUITE"], ax = ax[1], order = df["NAME_TYPE_SUITE"].value_counts().index,color='c',edgecolor='c')                                                                                               
plt.title("NAME_TYPE_SUITE");

# %% [markdown]
# ##### INTERPRETATION:UNACCOMPANIED HAS HIGEST PROPORTION WHEN THEY ARE APPLYING FOR LOAN.

# %%
data = df["NAME_EDUCATION_TYPE"].value_counts()                                  
pie, ax = plt.subplots(1, 2, figsize = [20,6])                                                             
labels =data.keys() 
colors=['#66b3ff','#99ff99','#ffcc99','#ff55cc','y']
ax[0].pie(x = data, autopct = "%.1f%%", labels = labels, pctdistance = 0.8,colors=colors,radius=2);
                                                                            
sns.countplot(x = df["NAME_EDUCATION_TYPE"], ax = ax[1], order = df["NAME_EDUCATION_TYPE"].value_counts().index,color='c',edgecolor='c')                                                                                               
plt.title("NAME_EDUCATION_TYPE");

# %% [markdown]
# ##### INTERPRETATION: MOST OF THE CLIENTS ACHIEVED HIGHEST EDUCATION AS SECONDARY SCHOOL.

# %%
data = df["NAME_FAMILY_STATUS"].value_counts()                                  
pie, ax = plt.subplots(1, 2, figsize = [20,6])                                                             
labels =data.keys() 
colors=['#66b3ff','#99ff99','#ffcc99','#ff55cc','y']
ax[0].pie(x = data, autopct = "%.1f%%", labels = labels, pctdistance = 0.8,colors=colors);
                                                                            
sns.countplot(x = df["NAME_FAMILY_STATUS"], ax = ax[1], order = df["NAME_FAMILY_STATUS"].value_counts().index,color='c',edgecolor='c')                                                                                               
plt.title("NAME_FAMILY_STATUS");

# %% [markdown]
# ##### INTERPRETATION: MOST OF THE CLIENTS ARE MARRIED WHO ARE APPLYING FOR LOAN.

# %%
data = df["MOBILE"].value_counts()                                  
pie, ax = plt.subplots(1, 2, figsize = [20,6])                                                             
labels =data.keys() 
colors=['#66b3ff','#99ff99']
ax[0].pie(x = data, autopct = "%.1f%%", labels = labels, pctdistance = 0.8,colors=colors);
                                                                            
sns.countplot(x = df["MOBILE"], ax = ax[1], order = df["MOBILE"].value_counts().index,color='c',edgecolor='c')                                                                                               
plt.title("MOBILE");

# %% [markdown]
# ##### INTERPRETATION: ALL CLIENTS HAVE MOBILE PHONES.

# %%
data = df["WORK_PHONE"].value_counts()                                  
pie, ax = plt.subplots(1, 2, figsize = [20,6])                                                             
labels =data.keys() 
colors=['#66b3ff','#99ff99']
ax[0].pie(x = data, autopct = "%.1f%%", labels = labels, pctdistance = 0.8,colors=colors);
                                                                            
sns.countplot(x = df["WORK_PHONE"], ax = ax[1], order = df["WORK_PHONE"].value_counts().index,color='c',edgecolor='c')                                                                                               
plt.title("WORK_PHONE");

# %% [markdown]
# ##### INTERPRETATION: 82.1% CLIENTS HAVE PROVIDE THEIR WORK PHONE NUMBERS.

# %%
data = df["HOME_PHONE"].value_counts()                                  
pie, ax = plt.subplots(1, 2, figsize = [20,6])                                                             
labels =data.keys() 
colors=['#66b3ff','#99ff99']
ax[0].pie(x = data, autopct = "%.1f%%", labels = labels, pctdistance = 0.8,colors=colors);
                                                                            
sns.countplot(x = df["HOME_PHONE"], ax = ax[1], order = df["HOME_PHONE"].value_counts().index,color='c',edgecolor='c')                                                                                               
plt.title("HOME_PHONE");

# %% [markdown]
# ##### INTERPRETATION: ONLY 20% CLIENTS HAVE PROVIDE THEIR HOME PHONE NUMBERS.

# %%
data = df["MOBILE_REACHABLE"].value_counts()                                  
pie, ax = plt.subplots(1, 2, figsize = [20,6])                                                             
labels =data.keys() 
colors=['#66b3ff','#99ff99']
ax[0].pie(x = data, autopct = "%.1f%%", labels = labels, pctdistance = 0.8,colors=colors);
                                                                            
sns.countplot(x = df["MOBILE_REACHABLE"], ax = ax[1], order = df["MOBILE_REACHABLE"].value_counts().index,color='c',edgecolor='c')                                                                                               
plt.title("MOBILE_REACHABLE");

# %% [markdown]
# ##### INTERPRETATION: 99.8% CLIENTS PHONES ARE REACHABLE.

# %%
data = df["FLAG_EMAIL"].value_counts()                                  
pie, ax = plt.subplots(1, 2, figsize = [20,6])                                                             
labels =data.keys() 
colors=['#66b3ff','#99ff99']
ax[0].pie(x = data, autopct = "%.1f%%", labels = labels, pctdistance = 0.8,colors=colors);
                                                                            
sns.countplot(x = df["FLAG_EMAIL"], ax = ax[1], order = df["FLAG_EMAIL"].value_counts().index,color='c',edgecolor='c')                                                                                               
plt.title("FLAG_EMAIL");

# %% [markdown]
# ##### INTERPRETATION: ONLY 5.6% CLIENTS HAVE PROVIDE THEIR EMAIL ID.

# %%
data = df["OCCUPATION_TYPE"].value_counts()                                  
pie, ax = plt.subplots(1, 2, figsize = [20,6])                                                             
labels =data.keys() 
colors=['#66b3ff','#99ff99','#ffcc99','#ff55cc','y']
ax[0].pie(x = data, autopct = "%.1f%%", labels = labels, pctdistance = 0.8,colors=colors);
                                                                            
sns.countplot(x = df["OCCUPATION_TYPE"], ax = ax[1], order = df["OCCUPATION_TYPE"].value_counts().index,color='c',edgecolor='c')                                                                                               
plt.title("OCCUPATION_TYPE");

# %% [markdown]
# ##### INTERPRETATION: MOST OF THE APPLICANTS HAVE OCCUPATION TYPE AS LABOURER.

# %%
data = df["CNT_FAM_MEMBERS"].value_counts()                                  
pie, ax = plt.subplots(1, 2, figsize = [20,6])                                                             
labels =data.keys() 
colors=['#66b3ff','#99ff99','#ffcc99','#ff55cc','y']
ax[0].pie(x = data, autopct = "%.1f%%", labels = labels, pctdistance = 0.8,colors=colors);
                                                                            
sns.countplot(x = df["CNT_FAM_MEMBERS"], ax = ax[1], order = df["CNT_FAM_MEMBERS"].value_counts().index,color='c',edgecolor='c')                                                                                               
plt.title("CNT_FAM_MEMBERS");

# %% [markdown]
# ##### INTERPRETATION: 51.7% CLIENTS HAVE 2 FAMILY MEMBERS.

# %%
data = df["APPLICATION_DAY"].value_counts()                                  
pie, ax = plt.subplots(1, 2, figsize = [20,6])                                                             
labels =data.keys() 
colors=['#66b3ff','#99ff99','#ffcc99','#ff55cc','y','r','orange']
ax[0].pie(x = data, autopct = "%.1f%%", labels = labels, pctdistance = 0.8,colors=colors);
                                                                            
sns.countplot(x = df["APPLICATION_DAY"], ax = ax[1], order = df["APPLICATION_DAY"].value_counts().index,color='c',edgecolor='c')                                                                                               
plt.title("APPLICATION_DAY");

# %% [markdown]
# ##### INTERPRETATION: MOST OF THE CLIENTS HAVE APPLIED FOR LOAN ON TUESDAY.

# %%
data = df["TOTAL_DOC_SUBMITTED"].value_counts()                                  
pie, ax = plt.subplots(1, 2, figsize = [20,6])                                                             
labels =data.keys() 
colors=['#66b3ff','#99ff99','orange']
ax[0].pie(x = data, autopct = "%.1f%%", labels = labels, pctdistance = 0.8,colors=colors);
                                                                            
sns.countplot(x = df["TOTAL_DOC_SUBMITTED"], ax = ax[1], order = df["TOTAL_DOC_SUBMITTED"].value_counts().index,color='c',edgecolor='c')                                                                                               
plt.title("TOTAL_DOC_SUBMITTED");

# %% [markdown]
# ##### INTERPRETATION: 87.9% CLIENTS HAVE SUBMITTED ONLY 1 DOCUMENT.

# %% [markdown]
# ## NUMERICAL

# %%
fig, ax = plt.subplots(1,2,figsize = (15,6))
sns.histplot(x = "SK_ID_CURR",data =df,ax=ax[0],color='c');
sns.boxplot(x = "SK_ID_CURR",data = df,ax=ax[1]);

# %% [markdown]
# ##### INTERPRETATION: DATA IS NORMALLY SKEWED HERE.

# %%
fig, ax = plt.subplots(1,2,figsize = (15,6))
sns.histplot(x = "AMT_INCOME_TOTAL",data =df,ax=ax[0],color='c',binrange=[20000,400000]);
sns.boxplot(x = "AMT_INCOME_TOTAL",data = df,ax=ax[1]);
plt.xlim([20000,400000]);

# %% [markdown]
# ##### INTERPRETATION: TOTAL INCOME AMOUNT HAS A RIGHT SKEWED DATA WITH MANY OUTLIERS WHICH IS THE NATURE OF DATA.

# %%
fig, ax = plt.subplots(1,2,figsize = (15,6))
sns.histplot(x = "AMT_CREDIT",data =df,ax=ax[0],color='c');
sns.boxplot(x = "AMT_CREDIT",data = df,ax=ax[1]);

# %% [markdown]
# ##### INTERPRETATION: TOTAL CREDIT AMOUNT HAS A RIGHT SKEWED DATA WITH MANY OUTLIERS WHICH IS THE NATURE OF DATA.

# %%
fig, ax = plt.subplots(1,2,figsize = (15,6))
sns.histplot(x = "AMT_GOODS_PRICE",data =df,ax=ax[0],color='c');
sns.boxplot(x = "AMT_GOODS_PRICE",data = df,ax=ax[1]);

# %% [markdown]
# ##### INTERPRETATION: TOTAL GOOD'S PRICE AMOUNT HAS A RIGHT SKEWED DATA WITH MANY OUTLIERS WHICH IS THE NATURE OF DATA.

# %%
fig, ax = plt.subplots(1,2,figsize = (15,6))
sns.histplot(x = "DAYS_EMPLOYED",data =df,ax=ax[0],color='c',binrange=(-15000,1000))
sns.boxplot(x = "DAYS_EMPLOYED",data = df,ax=ax[1]);
plt.xlim([0,-15000]);

# %% [markdown]
# ##### INTERPRETATION: TOTAL DAYS EMPLOYED HAS A LEFT SKEWED DATA WITH MANY OUTLIERS WHICH IS THE NATURE OF DATA.

# %% [markdown]
# ## LEVEL-2  BIVARIATE-ANALYSIS

# %% [markdown]
# ## CATEGORICAL-CATEGORICAL

# %%
sns.countplot(hue = df["TARGET"], x = df["NAME_CONTRACT_TYPE"],color='c',edgecolor='c')                                                                                               
plt.title("TARGET V/S CONTRACT TYPE");

# %% [markdown]
# ##### INTERPRETATION: VERY FEW DEFAULTER CLIENTS HAVE REVOLOVING LOANS, AND CLIENTS WITH PAYMENT DIFFICULTIES ARE MORE FOR CASH LOANS.

# %%
sns.countplot(hue = df["GENDER"], x = df["NAME_CONTRACT_TYPE"],color='c',edgecolor='c')                                                                                               
plt.title("GENDER V/S CONTRACT TYPE");

# %% [markdown]
# ##### INTERPRETATION: MOST OF THE MALE AND FEMALES HAVE CASH LOAN.

# %%
sns.countplot(hue = df["GENDER"], x = df["Car"],color='c',edgecolor='c')                                                                                               
plt.title("GENDER V/S CAR");

# %% [markdown]
# ##### INTERPRETATION: MOST OF THE MALE HAVE CAR AND MOST OF THE FEMALES DO NOT HAVE CARS.

# %%
sns.countplot(hue = df["Car"], x = df["House"],color='c',edgecolor='c')                                                                                               
plt.title("HOUSE V/S CAR");

# %% [markdown]
# ##### INTERPRETATION: MOST OF THE CLIENTS WHO HAVE HOUSE ALSO HAVE CAR.

# %%
sns.countplot(hue = df["GENDER"], x = df["CNT_CHILDREN"],color='c',edgecolor='c')                                                                                               
plt.title("GENDER V/S CHILDREN COUNT");

# %% [markdown]
# ##### INTERPRETATION: MOST OF THE FEMALES HAVE HIGHER CHILDREN COUNT THAN MALES.

# %%
fig, ax = plt.subplots(figsize = (10,4))
sns.countplot(hue = df["NAME_TYPE_SUITE"], x = df["NAME_INCOME_TYPE"],color='c',edgecolor='c')                                                                                               
plt.title("NAME_TYPE_SUITE V/S NAME_INCOME_TYPE");  
plt.xticks(rotation=45);

# %% [markdown]
# ##### INTERPRETATION: UNACCOMPANIED CLIENTS ARE MOST FOR WORKING INCOME TYPE.

# %%
fig, ax = plt.subplots(figsize = (10,5))
sns.countplot(hue = df["NAME_EDUCATION_TYPE"], x = df["NAME_INCOME_TYPE"],color='c',edgecolor='c')                                                                                               
plt.title("NAME_EDUCATION_TYPE V/S NAME_INCOME_TYPE");  
plt.xticks(rotation=45);

# %% [markdown]
# ##### INTERPRETATION: SECONDARY EDUCATION EDUCATION TYPE CLIENTS ARE MOST FOR WORKING INCOME TYPE

# %%
fig, ax = plt.subplots(figsize = (10,6))
sns.countplot(hue = df["NAME_FAMILY_STATUS"], x = df["NAME_INCOME_TYPE"],color='c',edgecolor='c')                                                                                               
plt.title("NAME_FAMILY_STATUS V/S NAME_INCOME_TYPE"); 
plt.xticks(rotation=45);

# %% [markdown]
# ##### INTERPRETATION: SINGLE & MARRIED CLIENTS ARE MOST FOR WORKING INCOME TYPE.

# %%
fig, ax = plt.subplots(figsize = (14,6))
sns.countplot(hue = df["NAME_FAMILY_STATUS"], x = df["NAME_EDUCATION_TYPE"],color='c',edgecolor='c')                                                                                               
plt.title("NAME_FAMILY_STATUS V/S NAME_EDUCATION_TYPE");

# %% [markdown]
# ##### INTERPRETATION: MOST OF THE CLIENTS WITH FAMILY STATUS ARE MOST FOR SECONDARY EDUCATION TYPE.

# %%
fig, ax = plt.subplots(figsize = (8,4))
sns.countplot(hue = df["WORK_PHONE"], x = df["FLAG_EMAIL"],color='c',edgecolor='c')                                                                                               
plt.title("WORK_PHONE V/S FLAG EMAIL");

# %% [markdown]
# ##### INTERPRETATION: MOST OF THE CLIENTS HAVE NOT PROVIDED THEIR WORK PHONE NUMBERS AND EMAIL ID.

# %%
fig, ax = plt.subplots(figsize = (9,4))
sns.countplot(hue = df["APPLICATION_DAY"], x = df["TOTAL_DOC_SUBMITTED"],color='c',edgecolor='c')                                                                                               
plt.title("APPLICATION_DAY V/S TOTAL_DOC_SUBMITTED");

# %% [markdown]
# ##### INTERPRETATION: MOST OF THE CLIENTS HAVE SUBMITTED ONLY ONE DOCUMENT IN WEEK.

# %%
fig, ax = plt.subplots(figsize = (15,5))
sns.countplot(hue = df["OCCUPATION_TYPE"], x = df["CNT_FAM_MEMBERS"],color='c',edgecolor='c')                                                                                               
plt.title("OCCUPATION_TYPE V/S CNT_FAM_MEMBERS");

# %% [markdown]
# ##### INTERPRETATION: MOST OF THE CLIENTS WITH FAMILY MEMBERS 2 HAVE OCCUPATION TYPE HAS HIGHEST COUNT.

# %%
fig, ax = plt.subplots(figsize = (9,5))
sns.countplot(hue = df["TARGET"], x = df["TOTAL_DOC_SUBMITTED"],color='c',edgecolor='c')                                                                                               
plt.title("TARGET  V/S TOTAL_DOC_SUBMITTED");

# %% [markdown]
# ##### INTERPRETATION:TARGET OF 1 HAS THE HIGHEST TOTAL DOCUMENT SUBMITTED AS 1.

# %%
fig, ax = plt.subplots(figsize = (10,5))
sns.countplot(hue = df["NAME_FAMILY_STATUS"], x = df["CNT_FAM_MEMBERS"],color='c',edgecolor='c')                                                                                               
plt.title("NAME_FAMILY_STATUS V/S CNT_FAM_MEMBERS");

# %% [markdown]
# ##### INTERPRETATION: MOST OF THE SINGLES HAVE FAMILY COUNT AS 1 AND MOST OF THE REST ALL HAVE FAMILY COUNT AS 2.

# %%
fig, ax = plt.subplots(figsize = (15,5))
sns.countplot(hue = df["NAME_INCOME_TYPE"], x = df["OCCUPATION_TYPE"],color='c',edgecolor='c')                                                                                               
plt.title("NAME_INCOME_TYPE V/S OCCUPATION_TYPE"); 
plt.xticks(rotation=45);

# %% [markdown]
# ##### INTERPRETATION: MOST OF THE INCOME TYPE HAS OCCUPATION AS LABOURER.

# %% [markdown]
# ## CATEGORICAL - NUMERICAL

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(hue = df["NAME_CONTRACT_TYPE"], x = df["AMT_CREDIT"], ax = ax[0],color='c')
sns.boxplot(y = df["AMT_CREDIT"], x = df["NAME_CONTRACT_TYPE"], ax = ax[1])
# Out:
# <AxesSubplot:xlabel='NAME_CONTRACT_TYPE', ylabel='AMT_CREDIT'>

# %% [markdown]
# ##### INTERPRETATION:CREDIT AMOUNT FOR CASH LOANS IS HIGHER AS COMPARED TO REVOLVING LOANS.

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(hue = df["NAME_INCOME_TYPE"], x = df["AMT_CREDIT"], ax = ax[0],color='c')
sns.boxplot(y = df["AMT_CREDIT"], x = df["NAME_INCOME_TYPE"], ax = ax[1]);
plt.xticks(rotation=45);

# %% [markdown]
# ##### INTERPRETATION: BUISNESSMAN HAS HIGHER CREDIT AMOUNT AS COMPARED TO ANOTHER.

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(hue = df["NAME_FAMILY_STATUS"], x = df["DAYS_EMPLOYED"], ax = ax[0],color='c',binrange=(-15000,40000))
sns.boxplot(x = df["NAME_FAMILY_STATUS"], y = df["DAYS_EMPLOYED"], ax = ax[1]);
plt.ylim(-15000,400000)
plt.xticks(rotation=45);

# %% [markdown]
# ##### INTERPRETATION: WIDOW HAS STARTED THE EMPLOYEEMENT MUCH BEFORE SUBMITTING APPLICATION.

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(hue = df["NAME_FAMILY_STATUS"], x = df["AMT_GOODS_PRICE"], ax = ax[0],color='c')
sns.boxplot(x = df["NAME_FAMILY_STATUS"], y = df["AMT_GOODS_PRICE"], ax = ax[1]);
plt.xticks(rotation=45);

# %% [markdown]
# ##### INTYERPRETATION: DATA IS RIGHT SKEWED FOR AMOUNT OF GOOD'S PRICE FOR EACH FAMILY STATUS.

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(hue = df["OCCUPATION_TYPE"], x = df["AMT_GOODS_PRICE"], ax = ax[0],color='c')
sns.boxplot(x = df["OCCUPATION_TYPE"], y = df["AMT_GOODS_PRICE"], ax = ax[1]);
plt.xticks(rotation=45);

# %% [markdown]
# ##### INTYERPRETATION: DATA IS RIGHT SKEWED FOR AMOUNT OF GOOD'S PRICE FOR EACH OCCUPATION TYPE.

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(hue = df["NAME_EDUCATION_TYPE"], x = df["AMT_GOODS_PRICE"], ax = ax[0],color='c')
sns.boxplot(x = df["NAME_EDUCATION_TYPE"], y = df["AMT_GOODS_PRICE"], ax = ax[1]);
plt.xticks(rotation=45);

# %% [markdown]
# ##### INTYERPRETATION: DATA IS RIGHT SKEWED FOR AMOUNT OF GOOD'S PRICE FOR MOST OF THE EDUCATION TYPE.

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(hue = df["TARGET"], x = df["AMT_GOODS_PRICE"], ax = ax[0],color='c')
sns.boxplot(x = df["TARGET"], y = df["AMT_GOODS_PRICE"], ax = ax[1]);

# %% [markdown]
# ##### INTERPRETATION: DATA IS RIGHT SKEWED FOR AMOUNT OF GOOD'S PRICE FOR EACH TARGET WITH 0 AS FOR MOST OF THE AMOUNT OF GOOD'S PRICE.

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(hue = df["TARGET"], x = df["AMT_CREDIT"], ax = ax[0],color='c')
sns.boxplot(x = df["TARGET"], y = df["AMT_CREDIT"], ax = ax[1]);

# %% [markdown]
# ##### INTERPRETATION: DATA IS RIGHT SKEWED FOR AMOUNT FOR CREDIT FOR EACH TARGET, WITH 0 AS FOR MOST OF THE AMOUNT FOR CREDIT.

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(hue = df["TARGET"], x = df["AMT_INCOME_TOTAL"], ax = ax[0],color='c',binrange=[20000,400000])
sns.boxplot(x = df["TARGET"], y = df["AMT_INCOME_TOTAL"], ax = ax[1]);
plt.ylim(20000,400000);

# %% [markdown]
# ##### INTERPRETATION: DATA IS RIGHT SKEWED FOR TOTAL INCOME FOR EACH TARGET ,WITH 0 AS FOR MOST OF THE INCOME AMOUNT .

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(hue = df["TARGET"], x = df["DAYS_EMPLOYED"], ax = ax[0],color='c',binrange=[-15000,0])
sns.boxplot(x = df["TARGET"], y = df["DAYS_EMPLOYED"], ax = ax[1]);
plt.ylim(0,-15000);

# %% [markdown]
# ##### INTERPRETATION: DATA IS LEFT SKEWED FOR DAYS EMPLOYED FOR EACH TARGET ,WITH 0 AS FOR MOST OF THE DAYS EMPLOYEED.

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(hue = df["OCCUPATION_TYPE"], x = df["DAYS_EMPLOYED"], ax = ax[0],color='c',binrange=[-15000,0])
sns.boxplot(x = df["OCCUPATION_TYPE"], y = df["DAYS_EMPLOYED"], ax = ax[1]);
plt.ylim(0,-15000);
plt.xticks(rotation=45);

# %% [markdown]
# ##### INTERPRETATION: DATA IS LEFT SKEWED FOR DAYS EMPLOYED FOR EACH OCCUPATION TYPE ,WITH MAXIMUM SPREAD FOR LABOURER.

# %% [markdown]
# ## NUMERICAL-NUMERICAL

# %%
sns.lmplot(x='AMT_INCOME_TOTAL',y='AMT_CREDIT',fit_reg=False,scatter_kws={"marker":"D","s":20},data=df)
plt.xlim([20000,400000]);

# %% [markdown]
# ##### INTERPRETATION: TOTAL INCOME AMOUNT HAS POSITVELY SKEWED RELATION WITH CREDIT AMOUNT.

# %%
sns.lmplot(x='AMT_GOODS_PRICE',y='AMT_CREDIT',fit_reg=False,scatter_kws={"marker":"D","s":20},data=df);

# %% [markdown]
# ##### INTERPRETATION: TOTAL GOOD'S AMOUNT HAS POSITVELY SKEWED RELATION WITH CREDIT AMOUNT.

# %%
sns.lmplot(y='AMT_GOODS_PRICE',x='AMT_INCOME_TOTAL',fit_reg=False,scatter_kws={"marker":"D","s":20},data=df)
plt.xlim([20000,400000]);

# %% [markdown]
# ##### INTERPRETATION: TOTAL INCOME AMOUNT HAS POSITVELY SKEWED RELATION WITH GOOD'S PRICE AMOUNT.

# %% [markdown]
# ## LEVEL-3 MULTIVARIATE ANALYSIS

# %%
data_df2=df[(df['TARGET']==0) &(df['House']=='Y') &(df["Car"]=='Y')]
h = sns.FacetGrid(data_df2 , col ="GENDER")
h.map(sns.histplot, "AMT_CREDIT",color='c',edgecolor='c')
plt.show()

# %% [markdown]
# ##### NTERPRETATION: BY APPLYING CONDTION FOR NON DEFAULTER CLIENTS HAVING HOUSE AND CAR, WE CAN SAY THAT GENDER IS RIGHT SKEWED WITH RESPECT TO CREDIT AMOUNT WHERE FOR MALE IT HAS MORE SPREAD.

# %%
data_df3=df[(df['TARGET']==0) &(df['House']=='Y') &(df["Car"]=='Y')]
h1 = sns.FacetGrid(data_df3 , col ="GENDER")
h1.map(sns.histplot, "AMT_INCOME_TOTAL",color='c',edgecolor='c')
plt.show()

# %% [markdown]
# ##### NTERPRETATION: BY APPLYING CONDTION FOR NON DEFAULTER CLIENTS HAVING HOUSE AND CAR, WE CAN SAY THAT GENDER IS RIGHT SKEWED WITH RESPECT TO TOTAL INCOME AMOUNT WHERE FOR MALE IT HAS MORE COUNT.

# %%
data_df4=df[(df['TARGET']==0) &(df['House']=='Y') &(df["Car"]=='Y')]
h2 = sns.FacetGrid(data_df4 , col ="GENDER")
h2.map(sns.histplot, "AMT_GOODS_PRICE",color='c',edgecolor='c')
plt.show()

# %% [markdown]
# ##### INTERPRETATION: BY APPLYING CONDTION FOR NON DEFAULTER CLIENTS HAVING HOUSE AND CAR, WE CAN SAY THAT GENDER IS RIGHT SKEWED WITH RESPECT TO GOOD'S AMOUNT WHERE FOR MALE IT HAS MORE SPREAD.

# %%
data_df4=df[(df['TARGET']==0) &(df['House']=='Y') &(df["Car"]=='Y')]
h2 = sns.FacetGrid(data_df4 , col ="GENDER")
h2.map(sns.histplot, "DAYS_EMPLOYED",color='c',edgecolor='c',binrange=(-15000,5000))
plt.show()

# %% [markdown]
# ##### INTERPRETATION: BY APPLYING CONDTION FOR NON DEFAULTER CLIENTS HAVING HOUSE AND CAR, WE CAN SAY THAT GENDER IS LEFT SKEWED WITH RESPECT TO DAYS EMPLOYEED WHERE MALE HAS MORE SPREAD.

# %%
data_df4=df[(df['TARGET']==0) &(df['House']=='Y') &(df["Car"]=='Y')]
h2 = sns.FacetGrid(data_df4 , col ="NAME_INCOME_TYPE")
h2.map(sns.histplot, "AMT_GOODS_PRICE",color='c',edgecolor='c')
plt.show()

# %% [markdown]
# ##### INTERPRETATION: BY APPLYING CONDTION FOR NON DEFAULTER CLIENTS HAVING HOUSE AND CAR, WE CAN SAY THAT TOTAL INCOME TYPE POSITIVELY SKEWED WITH RESPECT TO GOOD'S PRICE AMOUNT WHERE FOR WORKING TYPE IT HAS MORE SPREAD.

# %%
data_df4=df[(df['TARGET']==0) &(df['House']=='Y') &(df["Car"]=='Y')]
h2 = sns.FacetGrid(data_df4 , col ="NAME_INCOME_TYPE")
h2.map(sns.histplot, "AMT_CREDIT",color='c',edgecolor='c')
plt.show()

# %% [markdown]
# ##### INTERPRETATION: BY APPLYING CONDTION FOR NON DEFAULTER CLIENTS HAVING HOUSE AND CAR, WE CAN SAY THAT TOTAL INCOME TYPEI POSITIVELY SKEWED WITH RESPECT TO CREDIT AMOUNT WHERE FOR WORKING TYPE IT HAS MORE SPREAD..

# %%
data_df4=df[(df['TARGET']==0) &(df['House']=='Y') &(df["Car"]=='Y')]
h2 = sns.FacetGrid(data_df4 , col ="NAME_CONTRACT_TYPE")
h2.map(sns.histplot, "AMT_INCOME_TOTAL",color='c',edgecolor='c',binrange=[20000,400000]);

# %% [markdown]
# ##### INTERPRETATION: BY APPLYING CONDTION FOR NON DEFAULTER CLIENTS HAVING HOUSE AND CAR, WE CAN SAY THAT TOTAL INCOME HAS MORE SPREAD FOR CASH LOANS CONTRACT TYPE..

# %%
data_df5=df[(df['TARGET']==0) &(df['House']=='Y') &(df["Car"]=='Y')]
sns.lmplot(x='AMT_GOODS_PRICE',y='AMT_CREDIT',fit_reg=False,scatter_kws={"marker":"D","s":20},data=data_df5);

# %% [markdown]
# ##### INTERPRETATION: BY APPLYING CONDTION FOR NON DEFAULTER CLIENTS HAVING HOUSE AND CAR, WE CAN SAY THAT TOTAL AMOUNT FOR GOOD'S PRICE IS POSITVELY SKEWED WITH RESPECT TO CREDIT AMOUNT.

# %%
data_df5=df[(df['TARGET']==0) &(df['House']=='Y') &(df["Car"]=='Y')]
sns.lmplot(y='AMT_GOODS_PRICE',x='AMT_INCOME_TOTAL',fit_reg=False,scatter_kws={"marker":"D","s":20},data=data_df5)
plt.xlim([20000,400000]);

# %% [markdown]
# ##### INTERPRETATION: BY APPLYING CONDTION FOR NON DEFAULTER CLIENTS HAVING HOUSE AND CAR, WE CAN SAY THAT TOTAL INCOME IS POSITVELY SKEWED WITH RESPECT TO GOOD'S PRICE AMOUNT.

# %%
data_df6=df[(df['TARGET']==0) &(df['House']=='Y') &(df["Car"]=='Y')]
sns.lmplot(x='AMT_INCOME_TOTAL',y='AMT_CREDIT',fit_reg=False,scatter_kws={"marker":"D","s":20},data=data_df6)
plt.xlim([20000,400000]);

# %% [markdown]
# ##### INTERPRETATION: BY APPLYING CONDTION FOR NON DEFAULTER CLIENTS HAVING HOUSE AND CAR, WE CAN SAY THAT TOTAL INCOME IS POSITVELY SKEWED WITH RESPECT TO CREDIT AMOUNT.
