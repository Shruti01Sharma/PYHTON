# %% [markdown]
# # HACKATHON

# %% [markdown]
# ## THE SHOPPING CART PROGRAM

# %%
def cart():
    print("%35s"%("THE SHOPPING STORE"))
    print("%40s"%("ESSENTIAL ITEMS AVAILABLE"))
    print("%5s%15s%20s%20s"%("S.no.","Item ","Quantity","Cost/Item"))
    print("%5s%15s%20s%20s"%(1,"Biscuits",5,20.50))
    print("%5s%15s%20s%20s"%(2,"Cereals",10,90.00))
    print("%5s%15s%20s%20s"%(3,"Chicken",20,200.00))
    print("%5s%15s%20s%20s"%(4,"Oats",20,39.99))
    print("%5s%15s%20s%20s"%(5,"Rice",30,79.99))
    
    a=int(input("How many packets of biscuits you want to purcahse?   "))
    b=int(input("How many packets of Cereals you want to purcahse?   "))
    c=int(input("How many packets of Chicken you want to purcahse?   "))
    d=int(input("How many packets of Oats you want to purcahse?   "))
    e=int(input("How many packets of Rice you want to purcahse?   "))
    
    total=(a*20.5+b*90.0+c*200+d*39.99+e*79.99)
    print("TOTAL PRICE OF ITEMS PURCHASED==",total,"rs.")
    f=input("Enter your fullname==> ")
    g=input("Enter your full address==> ")
    distance=int(input("Enter distance 5km/10km/15km ==>"))
    delivery=distance*2
    print("DELIVERY CHARGES=", delivery," rs.")
    print("TOTAL BILL AMOUNT= TOTAL PRICE OF ITEMS PURCHASED +  DELIVERY CHARGES")
    print("TOTAL BILL AMOUNT=",total+delivery,"rs.")
    print("-------------------------------------------------------------------------------------")
    quantity=[5,10,20,20,30]
    cart=[a,b,c,d,e]
    print("Do you want to continue shopping?? ")
    h=input("Enter yes/no==>")
    new=[]
    if h.upper()=="YES":
        for i in range(len(quantity)):
            quantity[i]=quantity[i]-cart[i]
            new.append(quantity[i])
        print("UPDATED CART QUANTITY",new)
    else:
        print("THANK YOU FOR SHOPPING WITH US, HAVE A NICE DAY")


    def updated_list():
        print("%400s"%("ITEMS AVAILABLE NOW"))
        print("%35s"%("THE SHOPPING STORE"))
        print("%40s"%("ESSENTIAL ITEMS AVAILABLE"))
        print("%5s%15s%20s%20s"%("S.no.","Item ","Quantity","Cost/Item"))
        print("%5s%15s%20s%20s"%(1,"Biscuits",new[0],20.50))
        print("%5s%15s%20s%20s"%(2,"Cereals",new[1],90.00))
        print("%5s%15s%20s%20s"%(3,"Chicken",new[2],200.00))
        print("%5s%15s%20s%20s"%(4,"Oats",new[3],39.99))
        print("%5s%15s%20s%20s"%(5,"Rice",new[4],79.99))
        
        a1=int(input("How many packets of biscuits you want to purcahse?   "))
        b1=int(input("How many packets of Cereals you want to purcahse?   "))
        c1=int(input("How many packets of Chicken you want to purcahse?   "))
        d1=int(input("How many packets of Oats you want to purcahse?   "))
        e1=int(input("How many packets of Rice you want to purcahse?   "))
    
        total1=(a1*20.5+b1*90.0+c1*200+d1*39.99+e1*79.99)
        print("YOUR NAME==>",f)
        print("FULL ADDRESS==>",g)
        print("DELIVERY CHARGES==>",delivery) 
        print("TOTAL BILL AMOUNT ==>",total1+delivery+total,"rs.")
        print("THANK YOU FOR SHOPPING WITH US, HAVE A NICE DAY")
    updated_list()
cart()
# Out:
#                  THE SHOPPING STORE
#                ESSENTIAL ITEMS AVAILABLE
# S.no.          Item             Quantity           Cost/Item
#     1       Biscuits                   5                20.5
#     2        Cereals                  10                90.0
#     3        Chicken                  20               200.0
#     4           Oats                  20               39.99
#     5           Rice                  30               79.99
# How many packets of biscuits you want to purcahse?   4
# How many packets of Cereals you want to purcahse?   8
# How many packets of Chicken you want to purcahse?   9
# How many packets of Oats you want to purcahse?   8
# How many packets of Rice you want to purcahse?   9
# TOTAL PRICE OF ITEMS PURCHASED== 3641.83 rs.
# Enter your fullname==> SHRUTI SHARMA
# Enter your full address==> CHANDNI CHOWK,DELHI
# Enter distance 5km/10km/15km ==>10
# DELIVERY CHARGES= 20  rs.
# ...
